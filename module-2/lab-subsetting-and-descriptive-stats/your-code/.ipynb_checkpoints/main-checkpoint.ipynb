# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np
import pprint
from matplotlib import pyplot as plt

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp=pd.read_csv('.\Temp_States.csv',encoding='UTF-8')

# %% [markdown]
# #### Print `temp`

# %%
temp.head(10)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
#Tenemos dos datos de tipo string y un dato de tipo float.
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
temp[temp['State']=='New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp[temp['State']=='New York']['Temperature'].agg('mean')
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp['Temperature']>15][['City','State']]
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp[temp['Temperature']>15][['City','Temperature']]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[(temp['Temperature']>15)&(temp['Temperature']<20)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.groupby('State').agg(['mean','std'])
# Out:
#             Temperature
#                    mean       std
# State
# Connecticut   15.833333  1.964186
# New Jersey    21.111111  1.571348
# New York      10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee=pd.read_csv('.\employee.csv',encoding='UTF-8')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
#El dataframe se compone de 7 columnas cinco de las cuales son de tipo string y dos de tipo int.
#Parece raro que el salario sea de tipo int
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
#La distribución de las variables Salary y Years es una distribución que no se ajusta a una normal.
#Los datos parecen distribuirse en varios grupos o sub poblaciones. Podría ser interesante estudiar la relación
#Entre estas variables y la variable Title.
employee.hist(bins=20);

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee.Salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee.Salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[employee.Salary==employee.Salary.min()]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee.Name=='David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee.Name=='David'].Salary
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee.Title=='associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee.Title=='associate')& (employee.Salary>55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby('Years').agg('mean')
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby('Title').agg('mean')['Salary']
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()

# %%
# print first quartile here
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby('Gender').agg('mean')['Salary']
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee.groupby('Department').agg(['min','mean','max'])
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
def amplitud(serie):
    return serie.max()-serie.min()
employee.groupby('Department').agg('amplitud')
# Out:
#             Years  Salary
# Department
# HR              6      40
# IT              7      40
# Sales           1       0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders=pd.read_csv('./Orders.csv',encoding='UTF-8')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders.UnitPrice.mean()
# Out:
# 3.1161744805540756

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders.UnitPrice.agg(('min','max'))
# Out:
# min       0.00
# max    8142.75
# Name: UnitPrice, dtype: float64

# %%
# your answer here
orders.head(15)
# Out:
#     Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0            0     536365    85123A  2010     12    3     8
# 1            1     536365     71053  2010     12    3     8
# 2            2     536365    84406B  2010     12    3     8
# 3            3     536365    84029G  2010     12    3     8
# 4            4     536365    84029E  2010     12    3     8
# 5            5     536365     22752  2010     12    3     8
# 6            6     536365     21730  2010     12    3     8
# 7            7     536366     22633  2010     12    3     8
# 8            8     536366     22632  2010     12    3     8
# 9            9     536367     84879  2010     12    3     8
# 10          10     536367     22745  2010     12    3     8
# 11          11     536367     22748  2010     12    3     8
# 12          12     536367     22749  2010     12    3     8
# 13          13     536367     22310  2010     12    3     8
# 14          14     536367     84969  2010     12    3     8
#
# ...

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
#Muestro los Id de los clientes que provienen de España
orders[orders.Country=='Spain'].CustomerID.unique()
# Out:
# array([12557, 17097, 12540, 12551, 12484, 12539, 12510, 12421, 12502,
#        12462, 12507, 12541, 12547, 12597, 12545, 12596, 12354, 12417,
#        12455, 12450, 12548, 12556, 12550, 12546, 12454, 12448, 12544,
#        12538, 12445, 12442], dtype=int64)

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
len(orders[orders.Country=='Spain']['CustomerID'].value_counts())
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
#Agrupamos por CustomerId  y luego filtramos.
total_compras=orders.groupby('CustomerID')['Quantity'].sum()
idx = total_compras[total_compras>50].index
print(idx)
#orders[orders.CustomerID.isin(idx)].CustomerID.unique()
# Out:
# Int64Index([12346, 12347, 12348, 12349, 12350, 12352, 12354, 12355, 12356,
#             12357,
#             ...
#             18272, 18273, 18274, 18276, 18277, 18278, 18281, 18282, 18283,
#             18287],
#            dtype='int64', name='CustomerID', length=4091)

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
total=orders.groupby(['CustomerID','Country'])['Quantity'].sum().reset_index()
total[total.Country=='Spain']
# Out:
#       CustomerID Country  Quantity
# 7          12354   Spain       530
# 59         12417   Spain       267
# 62         12421   Spain       484
# 84         12442   Spain       182
# 86         12445   Spain        62
# 89         12448   Spain       243
# 91         12450   Spain       128
# 95         12454   Spain      1006
# 97         12455   Spain       566
# 103        12462   Spain       536
# 120        12484   Spain      2191
# 132        12502   Spain       820
# 135        12507   Spain       905
# 138        12510   Spain       353
# 161        12538   Spain       191
# 162        12539   Spain      2067
# 163        12540   Spain      6685
# 164        12541   Spain       680
# 165        12544   Spain       136
# 166        12545   Spain       523
# 167        12546   Spain       633
# 168        12547   Spain       134
# 169        12548   Spain        49
# 170        12550   Spain       569
# 171        12551   Spain       100
# 174        12556   Spain       358
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
free_orders=orders[orders.amount_spent==0]
free_orders.head(3)
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914         9302     537197     22841  2010     12    7    14
# 22539       33576     539263     22580  2010     12    4    14
# 25379       40089     539722     22423  2010     12    2    13
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 6914   round cake tin vintage green         1  2010-12-05 14:02:00        0.0
# 22539  advent calendar gingham sack         4  2010-12-16 14:36:00        0.0
# 25379      regency cakestand 3 tier        10  2010-12-21 13:45:00        0.0
#
#        CustomerID         Country  amount_spent
# 6914        12647         Germany           0.0
# 22539       16560  United Kingdom           0.0
# 25379       14911            EIRE           0.0

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
lunch_bag=orders[orders['Description'].str.match("lunch bag")]
lunch_bag.head(10)
# Out:
#      Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93           93     536378     20725  2010     12    3     9
# 172         174     536385     22662  2010     12    3     9
# 354         363     536401     22662  2010     12    3    11
# 359         368     536401     20725  2010     12    3    11
# 360         369     536401     22382  2010     12    3    11
# 361         370     536401     20726  2010     12    3    11
# 362         371     536401     22384  2010     12    3    11
# 402         411     536404     22383  2010     12    3    11
# 403         412     536404     20728  2010     12    3    11
# 404         413     536404     20727  2010     12    3    11
#
#                      Description  Quantity          InvoiceDate  UnitPrice  \
# 93       lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# 172  lunch bag dolly girl design        10  2010-12-01 09:56:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
lunch_bag_2011=orders[(orders['Description'].str.match("lunch bag")) & (orders['year']==2011)]
lunch_bag_2011.head(5)
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340       42678     540015     20725  2011      1    2    11
# 26341       42679     540015     20726  2011      1    2    11
# 26512       42851     540023     22382  2011      1    2    12
# 26513       42852     540023     20726  2011      1    2    12
# 26860       43616     540098     22384  2011      1    2    15
#
#                       Description  Quantity          InvoiceDate  UnitPrice  \
# 26340     lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# 26341          lunch bag woodland        10  2011-01-04 11:40:00       1.65
# 26512  lunch bag spaceboy design          2  2011-01-04 12:58:00       1.65
# 26513          lunch bag woodland         1  2011-01-04 12:58:00       1.65
# 26860     lunch bag pink polkadot         1  2011-01-04 15:50:00       1.65
#
#        CustomerID         Country  amount_spent
# 26340       13319  United Kingdom         16.50
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
#Una función de distribución con una fuerte asimetría hacia la izquierda.
orders_spain=orders[orders.Country=='Spain']['amount_spent']
orders_spain.hist()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders_agosto=orders[orders['month']==8]
orders_agosto.head(5)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
#
#                               Description  Quantity          InvoiceDate  \
# 199475       6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 199476          scandinavian reds ribbons       156  2011-08-01 08:30:00
# 199477    ivory hanging decoration  heart        24  2011-08-01 09:31:00
# 199478   single heart zinc t-light holder        12  2011-08-01 09:31:00
# 199479  hanging heart zinc t-light holder        12  2011-08-01 09:31:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 199475       1.45       17941  United Kingdom        139.20
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders_pais_agosto=orders.groupby(['Country','month'])['InvoiceNo'].count().reset_index()
orders_pais_agosto=orders_pais_agosto[orders_pais_agosto.month==8]
orders_pais_agosto
# Out:
#              Country  month  InvoiceNo
# 7          Australia      8        107
# 17           Austria      8         88
# 29           Belgium      8        194
# 39            Canada      8          5
# 46   Channel Islands      8        140
# 66           Denmark      8         16
# 78              EIRE      8        593
# 92           Finland      8         61
# 104           France      8        569
# 116          Germany      8        795
# 129          Iceland      8         22
# 134           Israel      8        171
# 143            Italy      8         95
# 161            Malta      8         55
# 170      Netherlands      8        280
# 179           Norway      8         77
# 191           Poland      8         17
# 202         Portugal      8         41
# 220            Spain      8        252
# 232           Sweden      8         40
# 244      Switzerland      8        267
# 261   United Kingdom      8      23105
# 270      Unspecified      8         23

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
media_agosto_paises=orders.groupby(['Country'])['amount_spent'].mean().reset_index()
media_agosto_paises
# Out:
#                  Country  amount_spent
# 0              Australia    116.895620
# 1                Austria     25.624824
# 2                Bahrain     32.258824
# 3                Belgium     20.283772
# 4                 Brazil     35.737500
# 5                 Canada     24.280662
# 6        Channel Islands     27.340160
# 7                 Cyprus     22.134169
# 8         Czech Republic     33.069600
# 9                Denmark     49.882474
# 10                  EIRE     36.687745
# 11    European Community     21.670833
# 12               Finland     32.913985
# 13                France     25.056827
# 14               Germany     25.311562
# 15                Greece     32.831172
# 16               Iceland     23.681319
# 17                Israel     29.119718
# 18                 Italy     23.064960
# 19                 Japan    116.561900
# 20               Lebanon     37.641778
# 21             Lithuania     47.458857
# 22                 Malta     24.335625
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
producto_mas_caro=orders[orders['UnitPrice']==orders['UnitPrice'].max()]
producto_mas_caro
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby('year').mean().amount_spent
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
